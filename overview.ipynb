# %%
from src.config import Config
from src.main import Exchange

# %%
exchange = Exchange()
historical_data = exchange.fetch_historical_data(Config)
print(historical_data)
# Out:
# count of candles =  10752
#                          open      high       low     close       volume
# timestamp
# 2022-07-01 00:00:00  19942.21  20918.35  19658.97  20295.08  15102.27957
# 2022-07-01 01:00:00  20295.09  20475.15  20260.00  20416.46   5242.15213
# 2022-07-01 02:00:00  20416.45  20552.29  20269.95  20300.69   3668.92227
# 2022-07-01 03:00:00  20300.68  20309.55  19688.00  19730.76   6570.88765
# 2022-07-01 04:00:00  19730.77  19773.71  19366.89  19409.23   7334.11812
# ...                       ...       ...       ...       ...          ...
# 2023-09-21 10:00:00  26747.30  26799.60  26635.37  26649.89   2590.02262
# 2023-09-21 11:00:00  26649.90  26792.65  26618.90  26730.78   1616.89197
# 2023-09-21 12:00:00  26730.77  26776.98  26559.01  26642.32   3116.80714
# 2023-09-21 13:00:00  26642.33  26655.00  26380.00  26419.86   4656.37053
# 2023-09-21 14:00:00  26419.87  26560.00  26377.70  26511.00   2224.92286
#
# [10752 rows x 5 columns]

# %%
historical_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10752 entries, 2022-07-01 00:00:00 to 2023-09-21 14:00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    10752 non-null  float64
#  1   high    10752 non-null  float64
#  2   low     10752 non-null  float64
#  3   close   10752 non-null  float64
#  4   volume  10752 non-null  float64
# dtypes: float64(5)
# memory usage: 504.0 KB

# %%
historical_data.describe()
# Out:
#                open          high           low         close         volume
# count  10752.000000  10752.000000  10752.000000  10752.000000   10752.000000
# mean   23583.415986  23659.872198  23504.887801  23584.031144    7070.436077
# std     4428.616548   4433.690928   4423.040822   4428.557568    7613.027998
# min    15648.230000  15769.990000  15476.000000  15649.520000       0.000000
# 25%    19821.855000  19904.225000  19745.122500  19822.282500    1437.628820
# 50%    23328.420000  23414.345000  23239.480000  23328.325000    5234.316260
# 75%    27389.015000  27466.255000  27290.255000  27389.020000    9696.762083
# max    31606.000000  31804.200000  31401.640000  31606.010000  137207.188600

# %%
import mplfinance as mpf

mpf.plot(historical_data, type='line', style='binance', title=f'{Config.symbol} - {Config.timeframe} Candlestick Chart')

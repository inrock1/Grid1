# %%
from src.config import Config
from src.main import Exchange

# %%
exchange = Exchange()
historical_data = exchange.fetch_historical_data(Config)
print(historical_data)
# Out:
# count of candles =  10080
#                          open      high       low     close       volume
# timestamp
# 2022-07-01 00:00:00  19942.21  20918.35  19658.97  20295.08  15102.27957
# 2022-07-01 01:00:00  20295.09  20475.15  20260.00  20416.46   5242.15213
# 2022-07-01 02:00:00  20416.45  20552.29  20269.95  20300.69   3668.92227
# 2022-07-01 03:00:00  20300.68  20309.55  19688.00  19730.76   6570.88765
# 2022-07-01 04:00:00  19730.77  19773.71  19366.89  19409.23   7334.11812
# ...                       ...       ...       ...       ...          ...
# 2023-08-24 10:00:00  26440.75  26478.00  26409.40  26475.98    716.96494
# 2023-08-24 11:00:00  26475.99  26541.64  26444.01  26444.02    965.12680
# 2023-08-24 12:00:00  26444.02  26444.02  26381.60  26390.08   1116.77374
# 2023-08-24 13:00:00  26390.08  26425.01  26291.39  26356.52   1498.51227
# 2023-08-24 14:00:00  26356.52  26374.00  26073.00  26116.05   3376.39411
#
# [10080 rows x 5 columns]

# %%
historical_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10080 entries, 2022-07-01 00:00:00 to 2023-08-24 14:00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    10080 non-null  float64
#  1   high    10080 non-null  float64
#  2   low     10080 non-null  float64
#  3   close   10080 non-null  float64
#  4   volume  10080 non-null  float64
# dtypes: float64(5)
# memory usage: 472.5 KB

# %%
historical_data.describe()
# Out:
#               open          high           low         close         volume
# count  10080.00000  10080.000000  10080.000000  10080.000000   10080.000000
# mean   23406.21335  23483.743283  23326.261225  23406.830343    7458.770481
# std     4516.47022   4522.354782   4509.830545   4516.409060    7697.694130
# min    15648.23000  15769.990000  15476.000000  15649.520000       0.000000
# 25%    19610.22250  19723.642500  19524.195000  19610.767500    1760.963927
# 50%    23017.60000  23108.700000  22931.385000  23018.135000    5699.077320
# 75%    27597.61500  27687.272500  27507.842500  27597.617500   10052.821420
# max    31606.00000  31804.200000  31401.640000  31606.010000  137207.188600

# %%
import mplfinance as mpf

import mplfinance as mpf
mpf.plot(historical_data, type='line', style='binance', title=f'{Config.symbol} - {Config.timeframe} Candlestick Chart')

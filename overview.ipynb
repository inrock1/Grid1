# %%
# from historical_data import historical_data, symbol, timeframe

from src.config import Config
from src.main_class import Exchange

# %%
exchange = Exchange()
historical_data = exchange.fetch_historical_data(Config)
historical_data.describe()
# Out:
#                open          high          low         close        volume
# count   1000.000000   1000.000000   1000.00000   1000.000000   1000.000000
# mean   22916.463620  22997.865420  22833.02623  22919.250170  13650.344489
# std     1196.374558   1207.040621   1191.38648   1200.057917   9542.301623
# min    19622.770000  19802.240000  19549.09000  19621.660000   2961.257600
# 25%    22141.495000  22226.780000  22071.40250  22141.542500   7778.499298
# 50%    23076.100000  23130.290000  22988.87000  23076.970000  10690.536660
# 75%    23753.105000  23837.505000  23660.15000  23754.100000  16020.941523
# max    25832.570000  26386.870000  25770.00000  25894.670000  80041.752040

# %%
historical_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1000 entries, 2023-02-01 00:00:00 to 2023-03-14 15:00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    1000 non-null   float64
#  1   high    1000 non-null   float64
#  2   low     1000 non-null   float64
#  3   close   1000 non-null   float64
#  4   volume  1000 non-null   float64
# dtypes: float64(5)
# memory usage: 46.9 KB

# %%
print(historical_data)
# Out:
#                          open      high       low     close       volume
# timestamp
# 2023-02-01 00:00:00  23125.13  23168.90  22997.10  23085.73  12121.64019
# 2023-02-01 01:00:00  23085.36  23184.29  23055.25  23123.09   9512.34705
# 2023-02-01 02:00:00  23123.10  23130.93  23078.50  23108.43   7108.81617
# 2023-02-01 03:00:00  23107.17  23134.59  23038.07  23130.19   6963.14876
# 2023-02-01 04:00:00  23130.70  23157.41  23107.83  23135.98   6849.16887
# ...                       ...       ...       ...       ...          ...
# 2023-03-14 11:00:00  24568.41  24820.00  24443.10  24743.04  36496.52800
# 2023-03-14 12:00:00  24743.05  26025.00  24458.04  25832.57  80041.75204
# 2023-03-14 13:00:00  25832.57  26386.87  25588.00  25759.64  66006.47052
# 2023-03-14 14:00:00  25762.88  26140.00  25633.88  25815.75  36964.27261
# 2023-03-14 15:00:00  25819.65  25959.27  25770.00  25894.67  27335.51996
#
# [1000 rows x 5 columns]

# %%
import mplfinance as mpf

mpf.plot(historical_data, type='candle', style='binance', title=f'{Config.symbol} - {Config.timeframe} Candlestick Chart')
# Out:
# C:\Users\kasko\projects\ML\Grid1\venv\Lib\site-packages\mplfinance\_arg_validators.py:84: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+

# %%
# historical_data.to_csv('historical_data.csv', index=False)

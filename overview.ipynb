# %%
from historical_data import historical_data, symbol, timeframe

# %%
historical_data.describe()
# Out:
#                open          high           low         close        volume
# count    720.000000    720.000000    720.000000    720.000000    720.000000
# mean   26227.782972  26289.396597  26164.239375  26224.240111   1411.102990
# std      710.795560    715.740963    697.521080    702.430077   1825.594154
# min    25020.660000  25133.380000  24901.000000  25020.660000    176.386970
# 25%    25862.725000  25906.750000  25819.600000  25862.735000    572.210070
# 50%    26037.905000  26072.535000  25991.270000  26037.900000    878.481755
# 75%    26212.917500  26290.597500  26131.782500  26212.915000   1510.161525
# max    29197.340000  29235.000000  29164.650000  29197.330000  23508.553510

# %%
historical_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 720 entries, 2023-08-16 10:00:00 to 2023-09-15 09:00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    720 non-null    float64
#  1   high    720 non-null    float64
#  2   low     720 non-null    float64
#  3   close   720 non-null    float64
#  4   volume  720 non-null    float64
# dtypes: float64(5)
# memory usage: 33.8 KB

# %%
print(historical_data.max())
# Out:
# open      29197.34000
# high      29235.00000
# low       29164.65000
# close     29197.33000
# volume    23508.55351
# dtype: float64

# %%
print(historical_data)
# Out:
#                          open      high       low     close      volume
# timestamp
# 2023-08-16 10:00:00  29167.60  29206.61  29164.65  29197.33   603.02983
# 2023-08-16 11:00:00  29197.34  29198.00  29147.94  29164.67   867.58935
# 2023-08-16 12:00:00  29164.67  29211.34  29047.09  29160.00  2143.21439
# 2023-08-16 13:00:00  29159.99  29177.69  29073.60  29088.62  1477.44199
# 2023-08-16 14:00:00  29088.62  29165.00  29050.47  29159.91  1042.06759
# ...                       ...       ...       ...       ...         ...
# 2023-09-15 05:00:00  26642.15  26642.83  26575.00  26588.99   517.23558
# 2023-09-15 06:00:00  26588.98  26609.88  26564.28  26576.02   487.28781
# 2023-09-15 07:00:00  26576.01  26594.83  26550.99  26565.69  1018.40995
# 2023-09-15 08:00:00  26565.69  26637.08  26540.61  26633.41   789.07818
# 2023-09-15 09:00:00  26633.41  26690.00  26616.67  26616.68   241.98465
#
# [720 rows x 5 columns]

# %%
import mplfinance as mpf

mpf.plot(historical_data, type='candle', style='binance', title=f'{symbol} - {timeframe} Candlestick Chart')
# Out:
# C:\Users\kasko\projects\ML\Grid1\venv\Lib\site-packages\mplfinance\_arg_validators.py:84: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+

# %%
# historical_data.to_csv('historical_data.csv', index=False)

# %%
# from historical_data import historical_data, symbol, timeframe

from src.config import Config
from src.main_class import Exchange

# %%
exchange = Exchange()
historical_data = exchange.fetch_historical_data(Config)
historical_data.describe()
# Out:
#                open          high           low         close        volume
# count    720.000000    720.000000    720.000000    720.000000    720.000000
# mean   23310.568250  23386.229000  23229.332556  23311.072389  12774.019641
# std      924.995214    940.410276    911.656108    925.020770   7626.708731
# min    21460.440000  21546.610000  21351.070000  21458.380000   4231.566320
# 25%    22878.447500  22933.647500  22807.812500  22878.170000   7826.824128
# 50%    23364.020000  23417.970000  23304.225000  23363.950000  10357.628080
# 75%    23885.312500  24005.027500  23785.555000  23885.567500  14949.407108
# max    25072.670000  25250.000000  24936.990000  25072.670000  56961.594260

# %%
historical_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 720 entries, 2023-02-01 00:00:00 to 2023-03-02 23:00:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    720 non-null    float64
#  1   high    720 non-null    float64
#  2   low     720 non-null    float64
#  3   close   720 non-null    float64
#  4   volume  720 non-null    float64
# dtypes: float64(5)
# memory usage: 33.8 KB

# %%
print(historical_data.max())
# Out:
#                          open      high       low     close       volume
# timestamp
# 2023-02-01 00:00:00  23125.13  23168.90  22997.10  23085.73  12121.64019
# 2023-02-01 01:00:00  23085.36  23184.29  23055.25  23123.09   9512.34705
# 2023-02-01 02:00:00  23123.10  23130.93  23078.50  23108.43   7108.81617
# 2023-02-01 03:00:00  23107.17  23134.59  23038.07  23130.19   6963.14876
# 2023-02-01 04:00:00  23130.70  23157.41  23107.83  23135.98   6849.16887
# ...                       ...       ...       ...       ...          ...
# 2023-03-02 19:00:00  23441.14  23507.97  23388.76  23463.99  14125.24813
# 2023-03-02 20:00:00  23463.40  23567.52  23425.09  23467.06  12613.16616
# 2023-03-02 21:00:00  23467.64  23474.09  23386.44  23408.65   6454.34131
# 2023-03-02 22:00:00  23409.47  23557.01  23408.65  23460.97   6018.14551
# 2023-03-02 23:00:00  23460.27  23504.01  23429.32  23465.32   5152.48457
#
# [720 rows x 5 columns]

# %%
print(historical_data)
# Out:
# C:\Users\kasko\projects\ML\Grid1\venv\Lib\site-packages\mplfinance\_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
import mplfinance as mpf

mpf.plot(historical_data, type='candle', style='binance', title=f'{symbol} - {timeframe} Candlestick Chart')

# %%
# historical_data.to_csv('historical_data.csv', index=False)
